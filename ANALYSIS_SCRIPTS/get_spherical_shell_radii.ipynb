# %%
import matplotlib.pyplot as plt


r = []
r_prev = 0
r_now = 25
r_max = 70
r.append(r_now)

# r_next = (17 * r_now ** 3 - 16 * r_prev ** 3) ** (1 / 3)
# r_prev, r_now = r_now, r_next
# r.append(r_now)

while r_now <= r_max:
    r_next = (2 * r_now ** 3 - r_prev ** 3) ** (1 / 3)
    r_prev, r_now = r_now, r_next
    print(f"r_now = {r_now:.2f}")
    r.append(r_now)

# while r_now <= r_max:
#     r_next = (2 * r_now ** 3 - r_prev ** 3) ** (1 / 3)
#     r_prev, r_now = r_now, r_next
#     print(f"r_now = {r_now}")
#     r.append(r_now)

plt.scatter([j for j in range(len(r))], r)
plt.grid()
plt.ylim((0, r_max+5))
print(f"N = {len(r)}")
print([round(i, 2) for i in r])
# Out:
# r_now = 31.50
# r_now = 36.06
# r_now = 39.69
# r_now = 42.75
# r_now = 45.43
# r_now = 47.82
# r_now = 50.00
# r_now = 52.00
# r_now = 53.86
# r_now = 55.60
# r_now = 57.24
# r_now = 58.78
# r_now = 60.25
# r_now = 61.66
# r_now = 63.00
# r_now = 64.28
# r_now = 65.52
# r_now = 66.71
# r_now = 67.86
# r_now = 68.97
# r_now = 70.05
# N = 22
# [25, 31.5, 36.06, 39.69, 42.75, 45.43, 47.82, 50.0, 52.0, 53.86, 55.6, 57.24, 58.78, 60.25, 61.66, 63.0, 64.28, 65.52, 66.71, 67.86, 68.97, 70.05]
